# %% [markdown]
# 作業1：
#
# Breast Cancer Wisconsin (Diagnostic) Data Set
# 1.你選的這組資料為何重要?
# 這組資料有乳房腫瘤良性及惡性的變數，以及其他30個特徵值
# 對於未來做預測有很大的貢獻程度
# 2.資料從何而來?
# kaggle datasets
# Also can be found on UCI Machine Learning Repository: https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29
# 3.蒐集而來的資料型態為何?
# csv檔
# 4.這組資料想解決的問題如何評估?
# 預測的Accuracy或Precision
#
#
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1.核心問題為何?
# 劃分成小區域，讓每台車都能夠負責一個區域的乘客，平均化平常繞路等客人的時間成本，以提高業績
# 假設每台車子的空車時間小於20分鐘
# 2.資料從何而來
# 首先先分析載客app一個月下來哪個地段比較常叫車，把地圖圖像資料化，可以以人數來劃分地區區段
# 3.蒐集而來的資料型態為何?
# 非結構化的圖檔，以及累計載客人數的表格csv檔
# 4.你要回答的問題，其如何評估?
# 做統計分析t檢定，計算劃分區域之後每位司機的平均空車時間是不是小於20分鐘

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 13.019

# %% [markdown]
# 練習時間
# 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# Hint: 如何取平方

# %%
def MeanSquareError(y, yp):
    MSE=sum((y - yp)**2) / len(y)
    return MSE
MSE = MeanSquareError(y, y_hat)
print("The Mean absolute error is %.3f" % (MSE))
# Out:
# The Mean absolute error is 256.071
